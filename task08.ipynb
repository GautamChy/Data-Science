# %% [markdown]
# <a href="https://colab.research.google.com/github/GautamChy/Data-Science-Journey/blob/main/task08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# . Encapsulation
# - Create a class Person with private attributes __name and __age.
# - Use getter and setter methods to access and modify these values.

# %%
class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    def get_name(self):
        return self.__name

    def set_name(self, name):
        self.__name = name

    def get_age(self):
        return self.__age

    def set_age(self, age):
        self.__age = age


p = Person("Alice", 25)
print(p.get_name(), p.get_age())
p.set_age(35)
print("Updated age:", p.get_age())
# Out:
# Alice 25
# Updated age: 35

# %% [markdown]
# Polymorphism
# - Create a function show_details(obj) that works with different classes.
# - Define the same method name (details()) in two or more classes.
# - Call show_details() with different objects to show polymorphism.

# %%
class Student:
    def details(self):
        print("I am a student")

class Teacher:
    def details(self):
        print("I am a teacher")

def show_details(obj):
    obj.details()

show_details(Student())
show_details(Teacher())
# Out:
# I am a student
# I am a teacher

# %% [markdown]
# Single Inheritance
# - Create a base class Vehicle with a method start().
# - Create a derived class Bike that inherits from Vehicle.
# - Bike should have its own method wheels() that prints "Two wheels".

# %%
class Vehicle:
    def start(self):
        print("Vehicle started")

class Bike(Vehicle):
    def wheels(self):
        print("Two wheels")

bike = Bike()
bike.start()
bike.wheels()
# Out:
# Vehicle started
# Two wheels

# %% [markdown]
# Multiple Inheritance
# - Create class Singer with method sing() and class Dancer with method dance().
# - Create a class Performer that inherits from both.
# - Create a Performer object and call both methods.

# %%
class Singer:
    def sing(self):
        print("Singing")

class Dancer:
    def dance(self):
        print("Dancing")

class Performer(Singer, Dancer):
    pass

performer = Performer()
performer.sing()
performer.dance()
# Out:
# Singing
# Dancing

# %% [markdown]
#  Hierarchical Inheritance
# - Create a base class Appliance.
# - Create two child classes: WashingMachine and Microwave.
# - WashingMachine should have a method wash(), and Microwave should have a method heat().
# - Create objects of both and call their respective methods.

# %%
class Appliance:
    pass

class WashingMachine(Appliance):
    def wash(self):
        print("Washing clothes")

class Microwave(Appliance):
    def heat(self):
        print("Heating food")

wm = WashingMachine()
mw = Microwave()

wm.wash()
mw.heat()
# Out:
# Washing clothes
# Heating food

# %% [markdown]
# Polymorphism Using a Loop
# - Create classes Pen and Pencil, both with a method write().
# - Loop through a list of objects (Pen and Pencil) and call write() on each object.

# %%
class Pen:
    def write(self):
        print("Writing with a pen")

class Pencil:
    def write(self):
        print("Writing with a pencil")

items = [Pen(), Pencil()]

for item in items:
    item.write()
# Out:
# Writing with a pen
# Writing with a pencil

# %% [markdown]
# Use Encapsulation to Protect Age
# - Create a class Person with private attribute __age.
# - Use set_age() to set the age.
# - If age is less than 0, print "Invalid age".
# - Use get_age() to return the age.

# %%
class Person:
    def __init__(self):
        self.__age = 0

    def set_age(self, age):
        if age < 0:
            print("Invalid age")
        else:
            self.__age = age

    def get_age(self):
        return self.__age

person = Person()
person.set_age(-5)
person.set_age(22)
print("Age:", person.get_age())
# Out:
# Invalid age
# Age: 22

# %% [markdown]
# Company Structure
# - Create class Company with method company_name().
# - Create class Department that inherits Company and adds department_name().
# - Create class Employee that inherits Department and adds employee_name().
# - Create an Employee object and call all the methods.

# %%
class Company:
    def company_name(self):
        print("ABC Company")

class Department(Company):
    def department_name(self):
        print("IT Department")

class Employee(Department):
    def employee_name(self):
        print("John Doe")

emp = Employee()
emp.company_name()
emp.department_name()
emp.employee_name()
# Out:
# ABC Company
# IT Department
# John Doe

# %% [markdown]
# Lambda to check if a Number is Positive
# - Write a lambda function that takes a number and returns True if it is positive, otherwise False.
# - Test it with different values like 5, -3, and 0

# %%
is_positive = lambda x: x > 0

print(is_positive(5))
print(is_positive(-3))
print(is_positive(0))
# Out:
# True
# False
# False

# %% [markdown]
# . Lambda to Get First Character of a String
# - Create a lambda function that takes a string and returns its first character.
# - Example: "apple" → 'a'

# %%
first_char = lambda s: s[0]

print(first_char("apple"))
# Out:
# a

# %% [markdown]
# Add 10 to All List Elements
# - Given a list [1, 2, 3, 4, 5],
# - Use map() and lambda to return a new list where 10 is added to each number.

# %%
numbers = [1, 2, 3, 4, 5]
result = list(map(lambda x: x + 10, numbers))

print(result)
# Out:
# [11, 12, 13, 14, 15]

# %% [markdown]
# Get Length of Each Word
# - Given a list ["apple", "banana", "kiwi"],
# - Use map() and lambda to return a list of lengths of each word.
# - → Output: [5, 6, 4]

# %%
words = ["apple", "banana", "kiwi"]
lengths = list(map(lambda w: len(w), words))

print(lengths)
# Out:
# [5, 6, 4]

# %% [markdown]
# Filter Numbers Greater Than 50
# - Given a list [10, 55, 60, 23, 90],
# - Use filter() and lambda to return only the numbers greater than 50.

# %%
nums = [10, 55, 60, 23, 90]
filtered = list(filter(lambda x: x > 50, nums))

print(filtered)
# Out:
# [55, 60, 90]

# %% [markdown]
# Create a Word by Joining Letters
# - Given a list of letters ['P', 'Y', 'T', 'H', 'O', 'N'],
# - Use reduce() and lambda to join them into a single word:  "PYTHON".

# %%
from functools import reduce

letters = ['P', 'Y', 'T', 'H', 'O', 'N']
word = reduce(lambda a, b: a + b, letters)

print(word)
# Out:
# PYTHON
