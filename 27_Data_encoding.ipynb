# %% [markdown]
# <a href="https://colab.research.google.com/github/GautamChy/Data-Science/blob/main/27_Data_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # Estimate

# %% [markdown]
# * It is an observed numerical value used to estimate an unknown population parameter.
# * It is two types:
#   - 1) Point Estimate : Single numerical value used to estimate the unknown population parameter.
#   * Sample mean is the point estimate of the population mean.
#   - 2) Interval Estimate: Range of values that is used to estimate the unknown population parameter.
#   * Interval estimate of population parameters are called confidence intervals.

# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# Inferential Stats: Conclusion or Inferences

# %% [markdown]
# Sample data is used to draw conclusion for population data.

# %% [markdown]
# Hypothesis Testing Mechanism
# * Null Hypothesis(H0) :  Default Assumption
# * Alternate Hypothesis(H1): Opposite of Null Hypothesis

# %% [markdown]
# Person Crime--> Court

# %% [markdown]
# * H0: Person is not guilty
# * H1 : Person is guilty

# %% [markdown]
# Experiments are performed --> Collect proof --> Statistical Analysis

# %% [markdown]
# Accept or reject the null hypothesis.

# %% [markdown]
# # Confidence Intervals and Margin of Error

# %% [markdown]
# Cl : It provides range of values in which the value we are estimating lies in this interval with confidence.

# %% [markdown]
# ![Screenshot 2026-06-09 at 4.08.46 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Bayes Theorem

# %% [markdown]
# Probability
# * 1 )  Independent Events
# * 2 ) Dependent Events

# %% [markdown]
# 1 ) Independent

# %% [markdown]
# For ex: Rolling a dice {1,2,3,4,5,6}

# %% [markdown]
# Pr(1) = 1/6, Pr(2) = 1/6

# %% [markdown]
# One event doesn't impact another event

# %% [markdown]
# Tossing a coing

# %% [markdown]
# Pr(H) = 0.5, Pr(T) = 0.5

# %% [markdown]
# NOTE:  ( euta doller ko sikha jatii sukai head or tail aayos, head aauda tail lai effect pardoina, tail aauda head lai effect pardoina).
# * It means agadee ko kura ley paxadee effect pardoina.

# %% [markdown]
# 2 ) Dependent Events

# %% [markdown]
# There are 3 yellow and 2 red marbles in a bag.

# %% [markdown]
# Pr(Y) = 3/5, Pr(R) = 2/5

# %% [markdown]
# One event impact another event

# %% [markdown]
# For example:

# %% [markdown]
# ![Screenshot 2026-06-09 at 4.45.30 PM.png](data:image/png;base64,...)

# %% [markdown]
# Conditional Probality
# * A,B = events
# * P(A/B) = Probability of A given B has happened
# * P(B/A) = Probability of B given A is true
# * P(A),P(B) = The independent probability of A and B.

# %% [markdown]
# NOTE: Conditional Probality vaney ko like aghee example01 ma find the probability from bag01 and different condition deko thiyo tyo nai ho Conditional Probability.
# * Simply like: Condition dinnu kunai kuram ma.

# %% [markdown]
# Datasets:
# * Independent features(Size, No. of Rooms, Location)
# * Dependent feature(Price)

# %% [markdown]
# Note: Machine learning ma features means columns bujhnu.
# * columns lai features bujhney.
# * features = columns

# %% [markdown]
# NOTE: Junn value lai predict garinchha tylai
# * Output features, Dependent features, or Target variable vaninxa.

# %% [markdown]
# ![Screenshot 2026-06-09 at 5.12.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# * E is output features( Dependent features) because we pedict the value of E
# * A is input features ( Independent features)
