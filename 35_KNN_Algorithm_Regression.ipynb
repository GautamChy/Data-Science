# %% [markdown]
# <a href="https://colab.research.google.com/github/GautamChy/Data-Science/blob/main/35_KNN_Algorithm_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression

# %%
from sklearn.datasets import make_regression

# %%
x,y = make_regression(n_samples = 1000, n_features = 2, random_state = 42)

# %%
x
# Out:
# array([[ 0.43004165,  0.38193545],
#        [ 1.5615112 ,  1.30174129],
#        [-0.56629773, -0.99053633],
#        ...,
#        [ 1.7722516 , -0.02751491],
#        [ 0.56390912,  1.38427282],
#        [ 1.69645637, -2.08192941]])

# %%
x.shape
# Out:
# (1000, 2)

# %%
y
# Out:
# array([ 1.83875383e+01,  6.33022437e+01, -4.40634991e+01, -2.62237930e+01,
#         1.18159607e+01,  8.39158760e+00, -1.70514801e+01, -4.11884511e+01,
#         6.62642407e+00,  3.44518522e+01, -1.55969123e+01,  3.63972034e+01,
#        -2.29579700e+00,  5.89310496e+01, -4.77572478e+01,  2.67855723e+00,
#        -1.95950711e+01,  5.49363192e+01,  2.51002061e+01, -5.34154264e+00,
#         1.03080357e+01, -5.89970937e+01, -6.88666498e+01,  9.77318499e+01,
#        -5.95309054e+01,  3.78311665e+01,  3.88723141e+01,  2.25707029e+00,
#        -6.82430997e+01, -3.27733603e+01, -2.39501404e-01,  5.74157173e+00,
#         2.95560217e+01,  1.49492582e+01,  8.72032067e+00, -2.97035883e+01,
#        -7.34638694e+01, -8.47551895e+01,  8.28675690e+01, -2.03970724e+01,
#         2.98462180e+01,  6.53238200e+01,  2.80492162e+01,  3.51427408e+01,
#         3.50781476e+00, -1.18418761e+01, -4.50843833e-01,  2.89939869e+01,
# ...

# %%
y.shape
# Out:
# (1000,)

# %%
# Train model
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.33 , random_state = 42)

# %%
# Import KNeighborsRegression
from sklearn.neighbors import KNeighborsRegressor

# %%
regression = KNeighborsRegressor()

# %%
regression
# Out:
# KNeighborsRegressor()

# %%
regression.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = regression.predict(x_test)

# %%
y_pred
# Out:
# array([ 1.92212157e+01,  6.38378395e+01,  5.39144254e+01,  8.88187227e+01,
#        -1.37103992e+00,  2.56747451e+00,  6.39890797e+00,  4.07210070e+01,
#         2.18180718e+00, -4.23454830e+01,  7.35060952e-01, -2.24910105e+00,
#         3.96101040e+01,  4.42603981e+01, -1.67273556e+01,  1.75388230e+01,
#         1.88852590e+01,  4.01213486e-01, -2.84148166e+01, -4.78879567e-01,
#        -2.02520357e+01,  1.23431384e+00, -9.18620380e+01,  4.53434244e+01,
#         5.24555051e+01,  5.03379171e+01,  2.26358632e+01,  7.58407891e+00,
#         8.41063215e+01, -3.45602165e+00, -5.79981589e+01, -7.61664924e+01,
#        -8.76681532e+00, -2.87696015e+01,  1.11023268e+00,  3.45008062e+00,
#         2.56705140e+01,  6.01369032e+01,  2.33454937e+01,  2.20243494e+01,
#         4.53706046e+00, -5.07970622e+01, -3.33067654e+01, -2.03102643e+01,
#        -4.65279298e+01,  8.52867774e+00, -4.21422664e+01, -9.62236252e+01,
# ...

# %%
# original data
y_test
# Out:
# array([ 1.72925853e+01,  6.30721604e+01,  5.70161825e+01,  9.74642673e+01,
#        -1.41296746e+00,  2.35112296e+00,  7.87739093e+00,  4.62084991e+01,
#         2.44077323e+00, -3.87118247e+01,  4.07821189e-01, -1.19086235e+00,
#         4.43507657e+01,  4.37251833e+01, -1.64029097e+01,  1.78993948e+01,
#         1.78884705e+01,  1.06681364e+00, -3.18645504e+01,  4.92792989e-01,
#        -2.33394441e+01,  3.69272624e+00, -1.05575696e+02,  4.59873035e+01,
#         5.30769375e+01,  5.32855354e+01,  2.17020779e+01,  5.75074537e+00,
#         9.70176955e+01, -5.80220907e+00, -6.10639401e+01, -7.82894390e+01,
#        -7.27207277e+00, -2.75062372e+01,  8.61667228e-01,  3.82891830e+00,
#         2.61699288e+01,  5.89786376e+01,  2.32089710e+01,  2.05247627e+01,
#         6.20181101e+00, -5.41619909e+01, -3.09137656e+01, -2.04903556e+01,
#        -4.65573687e+01,  8.58797111e+00, -4.43777187e+01, -1.04897556e+02,
# ...

# %%
# for regression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
print(r2_score(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.988038138857119
# 2.32756843283477
# 19.811177968557445
